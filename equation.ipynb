# %%
import calcul_analytique

dico = calcul_analytique.equations(True,True)
np_eq, param, eq = dico["numpy_equation"], dico["param"], dico["equation"]
# Out:
# w01
# -r_11 r_12 r_22^2 r_3/(k_1 r_22^2 r_3^2 + k_2 r_12^2 r_3^2 - k_3 r_12^2 r_22^2)
# w02
# -r_12^2 r_21 r_22 r_3/(k_1 r_22^2 r_3^2 + k_2 r_12^2 r_3^2 - k_3 r_12^2 r_22^2)
# b1
# (-b k_1 r_22^2 r_3 + b k_2 r_12^2 r_3)/(k_1 r_22^2 r_3^2 + k_2 r_12^2 r_3^2 - k_3 r_12^2 r_22^2)
# w01
# -r_11 r_12 r_22^2 r_3/(k_1 r_22^2 r_3^2 + k_2 r_12^2 r_3^2 - k_3 r_12^2 r_22^2)
# w02
# -r_12^2 r_21 r_22 r_3/(k_1 r_22^2 r_3^2 + k_2 r_12^2 r_3^2 - k_3 r_12^2 r_22^2)
# b1
# (-b k_1 r_22^2 r_3 + b k_2 r_12^2 r_3)/(k_1 r_22^2 r_3^2 + k_2 r_12^2 r_3^2 - k_3 r_12^2 r_22^2)
# 'Equations :'
# Théorème de la résultante ∑ = Barre1
# Eq(-F_1*sin(theta_1) - T_1*sin(theta_1) + X_01, 0)
# Eq(F_1*cos(theta_1) + T_1*cos(theta_1) + Y_01 - g*m_1, 0)
# Eq(-F_1*r_11 + T_1*r_12 + k_1*(-theta_10 + (-b - gamma_1*r_3)/r_12), 0)
# Théorème de la résultante ∑ = Barre2
# Eq(-F_2*sin(theta_2) - T_2*sin(theta_2) + X_02, 0)
# Eq(F_2*cos(theta_2) + T_2*cos(theta_2) + Y_02 - g*m_2, 0)
# Eq(-F_2*r_21 + T_2*r_22 + k_2*(-theta_20 + (b - gamma_1*r_3)/r_22), 0)
# Equations bielle linéarisées
# Eq(a - r_12*cos(theta_1) - r_3*cos(gamma_1), L)
# Eq(-b - gamma_1*r_3 - r_12*theta_1, 0)
# Eq(a - r_22*cos(theta_2) - r_3*cos(gamma_1), L)
# Eq(b - gamma_1*r_3 - r_22*theta_2, 0)
# Théorème de la résultante à S3 isolé
# Eq(-T_1*sin(gamma_1) - T_2*sin(gamma_1) + X_03, 0)
# Eq(T_1*cos(gamma_1) + T_2*cos(gamma_1) + Y_03 - g*m_3, 0)
# Eq(k_3*(gamma_1 - gamma_10) - r_3*(k_2*(-b + gamma_1*r_3) + r_22*(F_2*r_21 + k_2*theta_20))/r_22**2 - r_3*(k_1*(b + gamma_1*r_3) + r_12*(F_1*r_11 + k_1*theta_10))/r_12**2, 0)
# Variable à réutiliser grâce aux équations bielles
# Eq(theta_1, (-b - gamma_1*r_3)/r_12)
# Eq(theta_2, (b - gamma_1*r_3)/r_22)
# substitution dans les théorèmes des moments en O_1 et O_2
# Eq(-F_1*r_11 + T_1*r_12 + k_1*(-theta_10 + (-b - gamma_1*r_3)/r_12), 0)
# Eq(-F_2*r_21 + T_2*r_22 + k_2*(-theta_20 + (b - gamma_1*r_3)/r_22), 0)
# Expression de T et T'
# Eq(T_2, (k_2*(-b + gamma_1*r_3) + r_22*(F_2*r_21 + k_2*theta_20))/r_22**2)
# Eq(T_1, (k_1*(b + gamma_1*r_3) + r_12*(F_1*r_11 + k_1*theta_10))/r_12**2)
# substitution dans le théorème des moments en D
# Eq(k_3*(gamma_1 - gamma_10) - r_3*(k_2*(-b + gamma_1*r_3) + r_22*(F_2*r_21 + k_2*theta_20))/r_22**2 - r_3*(k_1*(b + gamma_1*r_3) + r_12*(F_1*r_11 + k_1*theta_10))/r_12**2, 0)
# Eq(gamma_1, r_3*(-F_1*r_11*r_12*r_22**2 - F_2*r_12**2*r_21*r_22 - b*k_1*r_22**2 + b*k_2*r_12**2)/(k_1*r_22**2*r_3**2 + k_2*r_12**2*r_3**2 - k_3*r_12**2*r_22**2))
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[1], line 4
#       1 import calcul_analytique
#       3 dico = calcul_analytique.equations(True,True)
# ----> 4 np_eq, param, eq = dico["numpy_equation"], dico["param"], dico["equation"]
#
# KeyError: 'numpy_equation'

# %%
import calcul_analytique
import sympy as sp
from random import randint

weights = [randint(-1000, 1000)/100 for i in range(3)]
print("poids", weights)

solu = calcul_analytique.trouver_param_real(weights)

print("optimalité de la solution", solu.optimality)
assert solu.optimality < 9e-3

param_value = solu.x
print(solu.x)
# les paramètres du problèmes n'ont pas une précision infinie
param_value = [round(e, 3) for e in param_value]
param_value.insert(3, param_value[1])  # r_22=r_12

data = calcul_analytique.equations(True)
w_expr, param = data["weight_expression"], data["param"]
r_11, r_12, r_21, r_2, r_3, k_1, k_2, k_3, b = param

for ii in range(len(w_expr)):
    e = sp.simplify(w_expr[ii].subs(
        {param[i]: param_value[i] for i in range(len(param))}))
    print("poids réel", e, "poids théoriques", weights[ii])
    assert abs(e-weights[ii]) < 0.5
# Out:
# poids [9.57, 6.43, -5.08]
# w01
# -r_11 r_12 r_22^2 r_3/(k_1 r_22^2 r_3^2 + k_2 r_12^2 r_3^2 - k_3 r_12^2 r_22^2)
# w02
# -r_12^2 r_21 r_22 r_3/(k_1 r_22^2 r_3^2 + k_2 r_12^2 r_3^2 - k_3 r_12^2 r_22^2)
# b1
# (-b k_1 r_22^2 r_3 + b k_2 r_12^2 r_3)/(k_1 r_22^2 r_3^2 + k_2 r_12^2 r_3^2 - k_3 r_12^2 r_22^2)
# -r_11*r_12*r_22**2*r_3/(k_1*r_22**2*r_3**2 + k_2*r_12**2*r_3**2 - k_3*r_12**2*r_22**2) - 9.57
# -r_11*r_12**3*r_3/(k_1*r_12**2*r_3**2 + k_2*r_12**2*r_3**2 - k_3*r_12**4) - 9.57
# -r_12**2*r_21*r_22*r_3/(k_1*r_22**2*r_3**2 + k_2*r_12**2*r_3**2 - k_3*r_12**2*r_22**2) - 6.43
# -r_12**3*r_21*r_3/(k_1*r_12**2*r_3**2 + k_2*r_12**2*r_3**2 - k_3*r_12**4) - 6.43
# b*r_3*(-k_1*r_22**2 + k_2*r_12**2)/(k_1*r_22**2*r_3**2 + k_2*r_12**2*r_3**2 - k_3*r_12**2*r_22**2) + 5.08
# b*r_3*(-k_1*r_12**2 + k_2*r_12**2)/(k_1*r_12**2*r_3**2 + k_2*r_12**2*r_3**2 - k_3*r_12**4) + 5.08
# [-r_11*r_12**3*r_3/(k_1*r_12**2*r_3**2 + k_2*r_12**2*r_3**2 - k_3*r_12**4) - 9.57, -r_12**3*r_21*r_3/(k_1*r_12**2*r_3**2 + k_2*r_12**2*r_3**2 - k_3*r_12**4) - 6.43, b*r_3*(-k_1*r_12**2 + k_2*r_12**2)/(k_1*r_12**2*r_3**2 + k_2*r_12**2*r_3**2 - k_3*r_12**4) + 5.08]
# optimalité de la solution 4.455573767656321e-07
# [ 1.29279954 -2.01176302  0.8686208   1.29468195  2.03438899  1.23885104
#   1.26872162  1.73539715]
# w01
# -r_11 r_12 r_22^2 r_3/(k_1 r_22^2 r_3^2 + k_2 r_12^2 r_3^2 - k_3 r_12^2 r_22^2)
# w02
# -r_12^2 r_21 r_22 r_3/(k_1 r_22^2 r_3^2 + k_2 r_12^2 r_3^2 - k_3 r_12^2 r_22^2)
# b1
# (-b k_1 r_22^2 r_3 + b k_2 r_12^2 r_3)/(k_1 r_22^2 r_3^2 + k_2 r_12^2 r_3^2 - k_3 r_12^2 r_22^2)
# poids réel 9.57613916603265 poids théoriques 9.57
# poids réel 6.43593575814569 poids théoriques 6.43
# poids réel -5.07727346485203 poids théoriques -5.08
